# %%
# %load imports.py
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
ti = pd.read_csv('../DATA/titanic3.csv')
ti
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
pt1 = pd.pivot_table(ti[['sex', 'survived']], index='sex', aggfunc="sum")
pt1
# Out:
#         survived
# sex
# female       339
# male         161

# %%
pt2 = pd.pivot_table(ti[['age', 'survived', 'sex', 'pclass']], index=['sex', 'pclass'], values=['age'], aggfunc={'age': ["min", "mean", "max"]})
pt2
# Out:
#                 age
#                 max       mean     min
# sex    pclass
# female 1       76.0  37.037594  2.0000
#        2       60.0  27.499191  0.9167
#        3       63.0  22.185307  0.1667
# male   1       80.0  41.029250  0.9167
#        2       70.0  30.815401  0.6667
#        3       74.0  25.962273  0.3333

# %%
df = pd.DataFrame({'Student Names' : ['Jenny', 'Singh', 'Charles', 'Richard', 'Veena'],
                   'Category' : ['Online', 'Offline', 'Offline', 'Offline', 'Online'],
                   'Gender' : ['Female', 'Male', 'Male', 'Male', 'Female'],
                  'Courses': ['Java', 'Spark', 'PySpark','Hadoop','C'],
                   'Fee': [15000, 17000, 27000, 29000, 12000],
                   'Discount': [1100, 800, 1000, 1600, 600]})
df['PercentDiscount'] = 100 * (df['Discount'] / df['Fee'])
df
# Out:
#   Student Names Category  Gender  Courses    Fee  Discount  PercentDiscount
# 0         Jenny   Online  Female     Java  15000      1100         7.333333
# 1         Singh  Offline    Male    Spark  17000       800         4.705882
# 2       Charles  Offline    Male  PySpark  27000      1000         3.703704
# 3       Richard  Offline    Male   Hadoop  29000      1600         5.517241
# 4         Veena   Online  Female        C  12000       600         5.000000

# %%
pt = pd.pivot_table(df, index=['Gender'], values=['Fee'], aggfunc="min")
pt
# Out:
#           Fee
# Gender
# Female  12000
# Male    17000

# %%
df.pivot(index='Gender', columns=['Discount'], values=['Fee'])
# Out:
#               Fee
# Discount     600      800      1000     1100     1600
# Gender
# Female    12000.0      NaN      NaN  15000.0      NaN
# Male          NaN  17000.0  27000.0      NaN  29000.0
